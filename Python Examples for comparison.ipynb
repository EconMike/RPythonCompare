# %%
#IDE

import pandas as pd
# Python code

#create data
df=p.DataFrame({'names':['5','8','9','10'],'grades':[76,95,77,78,]})

#Loading data

#check data type
# type(one)
# isinstance()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12864\3741390633.py in <module>
#       5
#       6 #create data
# ----> 7 df=p.DataFrame({'names':['5','8','9','10'],'grades':[76,95,77,78,]})
#       8
#       9 #Loading data
#
# NameError: name 'p' is not defined

# %%
#Visualization

import pandas as pd
# Python code

#create data
df=pd.DataFrame({'names':['5','8','9','10'],'grades':[76,95,77,78,]})

#Loading data

#check data type
# type(one)
# isinstance() 

# [slide 31]
#using python

data=pd.read_csv('iris_data.txt', sep=",", header=None,names=('A', 'B', 'C','D','E'))

# %%
# **Visualization

#visualization
#box plot

import matplotlib.pyplot as plt

plt.boxplot(df['grades'])
plt.show()

#box plot with title

y=[3, 10, 7, 5, 3, 6, 8]

plt.boxplot(y)
plt.title("Join WSS, FUn! ")
plt.show()

# %%
#create histogram
df=pd.DataFrame({'scores':[10,5,8,9,11],'height':[76,95,77,78,66]})

import numpy as np
np.histogram(df['scores'])
plt.hist(df['scores'])
plt.title("Histogram ")
# Out:
# Text(0.5, 1.0, 'Histogram ')

# %%
# **Statistical Analysis
# linear single regression

#for the OLS function
from statsmodels.formula.api import ols

#for the BP test
import statsmodels.stats.api as sms


import statsmodels.api as stats

#additional functionality
from statsmodels.compat import lzip

df = pd.read_csv('./PRAC_DATA.csv')

model1 = ols("PCE ~ WAG_S", data=df).fit()

print (model1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    PCE   R-squared:                       0.993
# Model:                            OLS   Adj. R-squared:                  0.993
# Method:                 Least Squares   F-statistic:                     3317.
# Date:                Mon, 13 Mar 2023   Prob (F-statistic):           2.26e-26
# Time:                        05:26:35   Log-Likelihood:                -169.14
# No. Observations:                  25   AIC:                             342.3
# Df Residuals:                      23   BIC:                             344.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1006.2594    155.342     -6.478      0.000   -1327.609    -684.910
# ...

# %%
import numpy as np
from scipy import stats

def jarque_bera(resids, axis=0):
    
    resids = np.asarray(resids)
    # Calculate residual skewness and kurtosis
    skew = stats.skew(resids, axis=axis)
    kurtosis = 3 + stats.kurtosis(resids, axis=axis)

    # Calculate the Jarque-Bera test for normality
    n = resids.shape[axis]
    jb = (n / 6.) * (skew ** 2 + (1 / 4.) * (kurtosis - 3) ** 2)
    jb_pv = stats.chi2.sf(jb, 2)

    return jb, jb_pv, skew, kurtosis

# %%
jarque_bera(model1.resid)
# Out:
# (1.889092872888568, 0.3888559017755715, -0.604766668680684, 2.407920390669889)

# %%
#Processing time

import pandas as pd
import timeit



stu_df =pd.DataFrame({'rating':[1,2,3,4],
                      'avg_sleep_hours':[21, 18, 17, 10],
                      'animal':['koala', 'hedgehog', 'sloth', 'panda'],
                      'country':['Australia', 'Italy', 'Peru', 'China']})

# %%
start = timeit.default_timer()
for (columnName, columnData) in stu_df.iteritems():
    print('Column Name : ', columnName)
    print('Column Contents : ', columnData.values)


# All the program statements
stop = timeit.default_timer()
execution_time = stop - start

print("Program Executed in "+str(execution_time)) # It returns time in seconds
# Out:
# Column Name :  rating
# Column Contents :  [1 2 3 4]
# Column Name :  avg_sleep_hours
# Column Contents :  [21 18 17 10]
# Column Name :  animal
# Column Contents :  ['koala' 'hedgehog' 'sloth' 'panda']
# Column Name :  country
# Column Contents :  ['Australia' 'Italy' 'Peru' 'China']
# Program Executed in 0.000595200002862839

# %%
df = pd.read_csv('iris_data.txt', sep=",", header=None,names=('A', 'B', 'C','D','E'))

# %%
df
# Out:
#        A    B    C    D               E
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
start = timeit.default_timer()
for index, row in df.iterrows():
    print(row['A']+ 1000 , row['B']+ 1000 )

stop = timeit.default_timer()
execution_time = stop - start
print(execution_time )
# Out:
# 1005.1 1003.5
# 1004.9 1003.0
# 1004.7 1003.2
# 1004.6 1003.1
# 1005.0 1003.6
# 1005.4 1003.9
# 1004.6 1003.4
# 1005.0 1003.4
# 1004.4 1002.9
# 1004.9 1003.1
# 1005.4 1003.7
# 1004.8 1003.4
# 1004.8 1003.0
# 1004.3 1003.0
# 1005.8 1004.0
# 1005.7 1004.4
# 1005.4 1003.9
# 1005.1 1003.5
# 1005.7 1003.8
# 1005.1 1003.8
# 1005.4 1003.4
# 1005.1 1003.7
# 1004.6 1003.6
# 1005.1 1003.3
# 1004.8 1003.4
# 1005.0 1003.0
# 1005.0 1003.4
# 1005.2 1003.5
# 1005.2 1003.4
# 1004.7 1003.2
# 1004.8 1003.1
# 1005.4 1003.4
# 1005.2 1004.1
# 1005.5 1004.2
# 1004.9 1003.1
# 1005.0 1003.2
# 1005.5 1003.5
# 1004.9 1003.1
# 1004.4 1003.0
# 1005.1 1003.4
# 1005.0 1003.5
# 1004.5 1002.3
# 1004.4 1003.2
# 1005.0 1003.5
# 1005.1 1003.8
# 1004.8 1003.0
# 1005.1 1003.8
# 1004.6 1003.2
# 1005.3 1003.7
# 1005.0 1003.3
# 1007.0 1003.2
# 1006.4 1003.2
# 1006.9 1003.1
# 1005.5 1002.3
# 1006.5 1002.8
# 1005.7 1002.8
# 1006.3 1003.3
# 1004.9 1002.4
# 1006.6 1002.9
# 1005.2 1002.7
# 1005.0 1002.0
# 1005.9 1003.0
# ...
